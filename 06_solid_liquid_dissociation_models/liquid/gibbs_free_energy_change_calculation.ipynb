# %%
#####################平衡电极电势U=0V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "Surfaces.db"       :  "表面",
    "Surfaces_Li2S4_bottomright.db" :  "吸附了Li2S4的表面",
    "Surfaces_Li2S2+2S.db" :  "吸附了Li2S2+2S的表面",
    "Surfaces_Li2S2_bottomright.db" :  "吸附了Li2S2的表面",
    "Surfaces_Li2S2-2.db" : "吸附了Li2S2的表面_1",
    "Surfaces_Li2S+S.db"   :  "吸附了Li2S+S的表面",
    "Surfaces_Li2S_bottomright.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第六行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-8.60E+00) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-8.60E+00)
        
        # 计算并添加"台阶数据"列
        df['台阶数据']                                =   df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值']                                =   df['台阶数据'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=0V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "Surfaces.db"       :  "表面",
    "Surfaces_Li2S4_bottomright.db" :  "吸附了Li2S4的表面",
    "Surfaces_Li2S2+2S.db" :  "吸附了Li2S2+2S的表面",
    "Surfaces_Li2S2-2.db" :  "吸附了Li2S2的表面",
    "Surfaces_Li2S2_bottomright.db" : "吸附了Li2S2的表面_1",
    "Surfaces_Li2S+S.db"   :  "吸附了Li2S+S的表面",
    "Surfaces_Li2S_bottomright.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第六行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-8.60E+00) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-8.60E+00)
        
        # 计算并添加"台阶数据"列
        df['台阶数据']                                =   df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值']                                =   df['台阶数据'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=0V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "Surfaces.db"       :  "表面",
    "Surfaces_Li2S4.db" :  "吸附了Li2S4的表面",
    "Surfaces_Li2S2+2S.db" :  "吸附了Li2S2+2S的表面",
    "Surfaces_Li2S2_bottomright.db" :  "吸附了Li2S2的表面",
    "Surfaces_Li2S2-2.db" : "吸附了Li2S2的表面_1",
    "Surfaces_Li2S+S.db"   :  "吸附了Li2S+S的表面",
    "Surfaces_Li2S_bottomright.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第六行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-8.60E+00) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-8.60E+00)
        
        # 计算并添加"台阶数据"列
        df['台阶数据']                                =   df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值']                                =   df['台阶数据'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=0V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "Surfaces.db"       :  "表面",
    "Surfaces_Li2S4.db" :  "吸附了Li2S4的表面",
    "Surfaces_Li2S2+2S.db" :  "吸附了Li2S2+2S的表面",
    "Surfaces_Li2S2_bottomright.db" :  "吸附了Li2S2的表面",
    "Surfaces_Li2S2-2.db" : "吸附了Li2S2的表面_1",
    "Surfaces_Li2S+S.db"   :  "吸附了Li2S+S的表面",
    "Surfaces_Li2S_bottomright.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第六行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-8.60E+00) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-8.60E+00)
        
        # 计算并添加"台阶数据"列
        df['台阶数据']                                =   df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值']                                =   df['台阶数据'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=2.30 V####################
from ase.db import connect
import pandas as pd


# 定义数据库文件的名称和对应描述
db_files = {
    "MoS2_stable_gap_1_supercell_optimized.db"       :  "表面",
    "MoS2_stable_gap_1_supercell_Li2S4_optimized.db" :  "吸附了Li2S4的表面",
    "MoS2_stable_gap_1_supercell_Li2S2+2S_optimized.db" :  "吸附了Li2S2+2S的表面",
    "MoS2_stable_gap_1_supercell_Li2S2_optimized.db" :  "吸附了Li2S2的表面",
    "MoS2_stable_gap_1_supercell_Li2S2_optimized_1.db" : "吸附了Li2S2的表面_1",
    "MoS2_stable_gap_1_supercell_Li2S+S_optimized.db"   :  "吸附了Li2S+S的表面",
    "MoS2_stable_gap_1_supercell_Li2S_optimized.db"  :  "吸附了Li2S的表面"
}


# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第五行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.01E+01) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-1.01E+01)
        
        # 计算并添加"台阶数据"列
        df['台阶数据'] = df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值'] = df['台阶数据'].diff()
        
        #加入电压矫正
        
        df['吉布斯自由能_U=2.19V'] = df['吉布斯自由能']  # 初始化新列

        # 然后可以根据需要更新特定行的值
        df.at["表面", '吉布斯自由能_U=2.19V']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能_U=2.19V']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能_U=2.19V'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能_U=2.19V']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01) + 2 * 2.19 
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能_U=2.19V']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 2.19  
        df.at["吸附了Li2S+S的表面", '吉布斯自由能_U=2.19V']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 2.19
        df.at["吸附了Li2S的表面", '吉布斯自由能_U=2.19V']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.01E+01) - df.at["表面", '能量'] + 6 * 2.19
        df.at["表面能量", '吉布斯自由能_U=2.19V']             =   df.at["表面能量", '能量'] + 4 * (-1.01E+01) + 6 * 2.19
        
        df['台阶数据_U=2.19V'] = df['吉布斯自由能_U=2.19V'] - df.loc['表面', '吉布斯自由能_U=2.19V']
        df['能量差值_U=2.19V'] = df['台阶数据_U=2.19V'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=3.62V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "MoS2_stable_gap_1_supercell_optimized.db"       :  "表面",
    "MoS2_stable_gap_1_supercell_Li2S4_optimized.db" :  "吸附了Li2S4的表面",
    "MoS2_stable_gap_1_supercell_Li2S2+2S_optimized.db" :  "吸附了Li2S2+2S的表面",
    "MoS2_stable_gap_1_supercell_Li2S2_optimized.db" :  "吸附了Li2S2的表面",
    "MoS2_stable_gap_1_supercell_Li2S2_optimized_1.db" : "吸附了Li2S2的表面_1",
    "MoS2_stable_gap_1_supercell_Li2S+S_optimized.db"   :  "吸附了Li2S+S的表面",
    "MoS2_stable_gap_1_supercell_Li2S_optimized.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第五行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        
        # 添加"吉布斯自由能"列并进行计算   
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.28E+01) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-1.28E+01)
        
        # 计算并添加"台阶数据"列
        df['台阶数据'] = df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值'] = df['台阶数据'].diff()
        
        #加入电压矫正
        
        df['吉布斯自由能_U=3.62V'] = df['吉布斯自由能']  # 初始化新列

        # 然后可以根据需要更新特定行的值
        df.at["表面", '吉布斯自由能_U=3.62V']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能_U=3.62V']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能_U=3.62V'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能_U=3.62V']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01) + 2 * 3.62 
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能_U=3.62V']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 3.62 
        df.at["吸附了Li2S+S的表面", '吉布斯自由能_U=3.62V']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 3.62
        df.at["吸附了Li2S的表面", '吉布斯自由能_U=3.62V']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.28E+01) - df.at["表面", '能量'] + 6 * 3.62
        df.at["表面能量", '吉布斯自由能_U=3.62V']             =   df.at["表面能量", '能量'] + 4 * (-1.28E+01) + 6 * 3.62
        
        
        df['台阶数据_U=3.62V'] = df['吉布斯自由能_U=3.62V'] - df.loc['表面', '吉布斯自由能_U=3.62V']
        df['能量差值_U=3.62V'] = df['台阶数据_U=3.62V'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=0V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "MoS2_stable_gap_0_supercell_optimized.db"       :  "表面",
    "MoS2_stable_gap_0_supercell_Li2S4_optimized.db" :  "吸附了Li2S4的表面",
    "MoS2_stable_gap_0_supercell_Li2S2+2S_optimized.db" :  "吸附了Li2S2+2S的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized.db" :  "吸附了Li2S2的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized_1.db" : "吸附了Li2S2的表面_1",
    "MoS2_stable_gap_0_supercell_Li2S+S_optimized.db"   :  "吸附了Li2S+S的表面",
    "MoS2_stable_gap_0_supercell_Li2S_optimized.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第六行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-8.60E+00) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-8.60E+00)
        
        # 计算并添加"台阶数据"列
        df['台阶数据']                                =   df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值']                                =   df['台阶数据'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=2.30 V####################
from ase.db import connect
import pandas as pd


# 定义数据库文件的名称和对应描述
db_files = {
    "MoS2_stable_gap_0_supercell_optimized.db"       :  "表面",
    "MoS2_stable_gap_0_supercell_Li2S4_optimized.db" :  "吸附了Li2S4的表面",
    "MoS2_stable_gap_0_supercell_Li2S2+2S_optimized.db" :  "吸附了Li2S2+2S的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized.db" :  "吸附了Li2S2的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized_1.db" : "吸附了Li2S2的表面_1",
    "MoS2_stable_gap_0_supercell_Li2S+S_optimized.db"   :  "吸附了Li2S+S的表面",
    "MoS2_stable_gap_0_supercell_Li2S_optimized.db"  :  "吸附了Li2S的表面"
}


# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第五行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        # 添加"吉布斯自由能"列并进行计算
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.01E+01) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-1.01E+01)
        
        # 计算并添加"台阶数据"列
        df['台阶数据'] = df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值'] = df['台阶数据'].diff()
        
        #加入电压矫正
        
        df['吉布斯自由能_U=2.19V'] = df['吉布斯自由能']  # 初始化新列

        # 然后可以根据需要更新特定行的值
        df.at["表面", '吉布斯自由能_U=2.19V']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能_U=2.19V']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能_U=2.19V'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能_U=2.19V']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01) + 2 * 2.19 
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能_U=2.19V']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 2.19  
        df.at["吸附了Li2S+S的表面", '吉布斯自由能_U=2.19V']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 2.19
        df.at["吸附了Li2S的表面", '吉布斯自由能_U=2.19V']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.01E+01) - df.at["表面", '能量'] + 6 * 2.19
        df.at["表面能量", '吉布斯自由能_U=2.19V']             =   df.at["表面能量", '能量'] + 4 * (-1.01E+01) + 6 * 2.19
        
        df['台阶数据_U=2.19V'] = df['吉布斯自由能_U=2.19V'] - df.loc['表面', '吉布斯自由能_U=2.19V']
        df['能量差值_U=2.19V'] = df['台阶数据_U=2.19V'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)

# %%
#####################平衡电极电势U=3.62V####################
from ase.db import connect
import pandas as pd

# 定义数据库文件的名称和对应描述
db_files = {
    "MoS2_stable_gap_0_supercell_optimized.db"       :  "表面",
    "MoS2_stable_gap_0_supercell_Li2S4_optimized.db" :  "吸附了Li2S4的表面",
    "MoS2_stable_gap_0_supercell_Li2S2+2S_optimized.db" :  "吸附了Li2S2+2S的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized.db" :  "吸附了Li2S2的表面",
    "MoS2_stable_gap_0_supercell_Li2S2_optimized_1.db" : "吸附了Li2S2的表面_1",
    "MoS2_stable_gap_0_supercell_Li2S+S_optimized.db"   :  "吸附了Li2S+S的表面",
    "MoS2_stable_gap_0_supercell_Li2S_optimized.db"  :  "吸附了Li2S的表面"
}

# 创建一个字典来保存每个数据库的连接
db_connections = {}

# 连接到每个数据库文件并获取其能量数据
for db_file, description in db_files.items():
    db = connect(db_file)
    db_connections[description] = db

# 循环遍历每个模型，创建并写入对应的excel文件
for i in range(1, len(db) + 1):
    # 从数据库中获取模型名称
    model_name = db_connections["表面"].get(i).formula

    # 创建一个新的excel文件，名称基于模型名称
    with pd.ExcelWriter(f'{model_name}.xlsx', engine='openpyxl') as writer:
    
        # 创建一个数据字典来存储每个数据库中的数据
        data = {}
        for description, db in db_connections.items():
            # 获取每个数据库中对应模型的能量数据
            energy = db.get(i).energy
            
            # 将数据添加到字典中
            data[description] = [description, energy]
            
        # 添加"表面"的能量数据到第五行
        surface_energy = db_connections["表面"].get(i).energy
        data["表面能量"] = ["表面能量", surface_energy]
        
        # 将数据字典转换为pandas DataFrame
        df = pd.DataFrame.from_dict(data, orient='index', columns=['名称', '能量'])
        
        
        # 添加"吉布斯自由能"列并进行计算   
        df['吉布斯自由能']                            =   df['能量']  # 初始化列
        df.at["表面", '吉布斯自由能']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01)
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量']
        df.at["吸附了Li2S+S的表面", '吉布斯自由能']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] 
        df.at["吸附了Li2S的表面", '吉布斯自由能']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.28E+01) - df.at["表面", '能量'] 
        df.at["表面能量", '吉布斯自由能']             =   df.at["表面能量", '能量'] + 4 * (-1.28E+01)
        
        # 计算并添加"台阶数据"列
        df['台阶数据'] = df['吉布斯自由能'] - df.loc['表面', '吉布斯自由能']
        df['能量差值'] = df['台阶数据'].diff()
        
        #加入电压矫正
        
        df['吉布斯自由能_U=3.62V'] = df['吉布斯自由能']  # 初始化新列

        # 然后可以根据需要更新特定行的值
        df.at["表面", '吉布斯自由能_U=3.62V']                 =   df.at["表面", '能量'] + (-2.24E+01) + 6 * (-6.61E-01)
        df.at["吸附了Li2S4的表面", '吉布斯自由能_U=3.62V']    =   df.at["吸附了Li2S4的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2+2S的表面", '吉布斯自由能_U=3.62V'] =   df.at["吸附了Li2S2+2S的表面", '能量'] + 6 * (-6.61E-01)
        df.at["吸附了Li2S2的表面", '吉布斯自由能_U=3.62V']    =   df.at["吸附了Li2S2的表面", '能量'] + (-1.37E+01) + 4 * (-6.61E-01) + 2 * 3.62 
        df.at["吸附了Li2S2的表面_1", '吉布斯自由能_U=3.62V']  =   2 * df.at["吸附了Li2S2的表面_1", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 3.62 
        df.at["吸附了Li2S+S的表面", '吉布斯自由能_U=3.62V']   =   2 * df.at["吸附了Li2S+S的表面", '能量'] + 4 * (-6.61E-01) - df.at["表面", '能量'] + 2 * 3.62
        df.at["吸附了Li2S的表面", '吉布斯自由能_U=3.62V']     =   2 * df.at["吸附了Li2S的表面", '能量'] + 2 * (-1.28E+01) - df.at["表面", '能量'] + 6 * 3.62
        df.at["表面能量", '吉布斯自由能_U=3.62V']             =   df.at["表面能量", '能量'] + 4 * (-1.28E+01) + 6 * 3.62
        
        
        df['台阶数据_U=3.62V'] = df['吉布斯自由能_U=3.62V'] - df.loc['表面', '吉布斯自由能_U=3.62V']
        df['能量差值_U=3.62V'] = df['台阶数据_U=3.62V'].diff()
        
        # 将DataFrame写入到excel文件中
        df.to_excel(writer, sheet_name=model_name, index=False)
