# %%
# 基本用法（假设频率单位为 THz）
# !python epc_viz.py --a2f alpha2F_THz.dat --lamcum lambda_cumul_THz.dat
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# [OK] 输出目录: c:\Users\ASUS\Desktop\Phonon进一步研究\Sc-HfO2\contribution_frequency
# 生成文件: plot_alpha2F.png, plot_dlamdw.png, plot_cumul_lambda.png, plot_lambda_bands.png
# 以及 epc_summary.csv, tc_table.csv, lambda_band_contributions.csv

# %%
# 如果只有 α²F 文件（没有累计 λ），也可以：
# !python epc_viz.py --a2f alpha2F_THz.dat

# %%
# 可选：自定义 μ* 列表、频段分箱、输出目录等
# !python epc_viz.py --a2f alpha2F_THz.dat --lamcum lambda_cumul_THz.dat --mu 0.10 0.12 0.15 --bins 0 2 4 6 8 10 12 15 20 25 --out EPC_OUT
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# [OK] 输出目录: c:\Users\ASUS\Desktop\Phonon进一步研究\contribution_frequency\EPC_OUT
# 生成文件: plot_alpha2F.png, plot_dlamdw.png, plot_cumul_lambda.png, plot_lambda_bands.png
# 以及 epc_summary.csv, tc_table.csv, lambda_band_contributions.csv

# %%
# 如果你的 α²F 频率单位是 meV，指定 --unit meV
# !python epc_viz.py --a2f alpha2F_meV.dat --unit meV
# Out:
# Traceback (most recent call last):
#   File "c:\Users\ASUS\Desktop\Phonon进一步研究\contribution_frequency\epc_viz.py", line 250, in <module>
#     main()
#   File "c:\Users\ASUS\Desktop\Phonon进一步研究\contribution_frequency\epc_viz.py", line 112, in main
#     A = read_two_col(args.a2f)
#   File "c:\Users\ASUS\Desktop\Phonon进一步研究\contribution_frequency\epc_viz.py", line 37, in read_two_col
#     with open(path, "r", encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'alpha2F_meV.dat'
