# %%
import os
from ase.db import connect
from ase.build import add_adsorbate
from ase.io import read

# 原始数据库
db_original = connect('initial_db.db')
# 新的数据库，用于保存带有Li吸附的结果
db_ads = connect('initial_db_S.db')

# 吸附原子和吸附高度（与表面最高原子之间的距离）
adsorbate = 'S'
z_ads_1 = 2  # 你可以改成 3.0 或者 4.2，视情况而定

for row in db_original.select():
    # 从数据库中读取原子结构
    atoms = row.toatoms()
    
    # 找到当前结构的 x-y 范围，以及最高 z
    positions = atoms.get_positions()
    x_min, y_min = positions[:, 0].min(), positions[:, 1].min()
    x_max, y_max = positions[:, 0].max(), positions[:, 1].max()
    z_max = positions[:, 2].max()
    
    # 计算 x-y 中心点
    center_x = 0.5 * (x_min + x_max)
    center_y = 0.5 * (y_min + y_max)
    
    # 拷贝一份结构，用于添加吸附原子
    atoms_ads = atoms.copy()
    
    # 在最高原子之上 z_ads_1 处放置 Li
    # add_adsorbate 的用法：add_adsorbate(slab, adsorbate, height, (x, y))
    # ASE 会自动将 adsorbate 放在 slab 最高原子之上再加上 height
    add_adsorbate(atoms_ads, adsorbate, z_ads_1, (center_x, center_y))
    
    # 将新的带有 Li 的结构写入数据库
    # 如果原数据库里没有 formula，可以改成 row.id 或者别的字段
    model_name = row.formula if row.formula else f"model_{row.id}"
    db_ads.write(atoms_ads, model=model_name)
    
    print(f"Added S on top of model {model_name} (id={row.id}).")
# Out:
# Added S on top of model Hf12O22 (id=1).
# Added S on top of model Nb14O32 (id=2).
# Added S on top of model V12O26 (id=3).
# Added S on top of model Sc64O90 (id=4).
# Added S on top of model Y64O78 (id=5).
# Added S on top of model Ta3O7 (id=6).
# Added S on top of model Ti6O10 (id=7).
# Added S on top of model W8O14 (id=8).
# Added S on top of model Zr8O16 (id=9).
